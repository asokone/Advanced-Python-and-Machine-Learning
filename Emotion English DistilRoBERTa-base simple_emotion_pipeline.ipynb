# %% [markdown]
# <a href="https://colab.research.google.com/github/asokone/Advanced-Python-and-Machine-Learning/blob/main/Emotion%20English%20DistilRoBERTa-base%20simple_emotion_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline
classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True)

# %%
classifier("I love this!")
